# %% [markdown]
# ## Mi Pc es una basura?

# %%
Before

# %%
dp.Image("/Users/samuu_159/Capturas/Captura de Pantalla 2022-09-29 a las 15.59.35.png")

# %%
from IPython import display as dp
# Out:
# <module 'IPython.display' from '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/IPython/display.py'>

# %%
def fib(n):
    if n in {0,1}:
        return n
    else:
        return(fib(n-1)+fib(n-2))

# %%
fib(30)

# %%
After

# %%
dp.Image("After.png")

# %%
import threading as th

# %%
import multiprocessing as mp

# %%
mp.cpu_count
# Out:
# <bound method BaseContext.cpu_count of <multiprocessing.context.DefaultContext object at 0x1084f7f40>>

# %%
mp.Pool
# Out:
# <bound method BaseContext.Pool of <multiprocessing.context.DefaultContext object at 0x1084f7f40>>
